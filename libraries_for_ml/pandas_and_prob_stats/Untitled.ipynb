# %%
import json
import requests
import matplotlib as plt

CLIENT_ID = "9b095388d326a10bf6c20b4d44db2aae607cb8978d9b.api.hackerearth.com"
CLIENT_SECRET = "3205893c5014470c0bc86b733be0b672d3585c52"
CHALLENGE_SLUG = "january-easy-16"

payload = {
    'client_id': CLIENT_ID,
    'client_secret': CLIENT_SECRET,
    'challenge_slug': CHALLENGE_SLUG,
    'page_index': 3
}
r = requests.post("https://api.hackerearth.com/challenges/v1/leaderboard/", data=json.dumps(payload))
data = r.json()
leaderboard = data['leaderboard']
for i in leaderboard:
    print(i['name'])
    print(i['score'])
# Out:
# Saravanaganesh S
# 240
# Abhinav sharma
# 240
# Bhishma Raj
# 240
# Divya Gupta
# 240
# Virendra Malav
# 240
# Dheerendra Malav
# 237
# bp
# 232
# Prabhu Dayal Sahoo
# 224
# Prachi Agrawal
# 222
# ude
# 220
# akshay goel
# 220
# Karan Deep Batra
# 218
# Pawan Kumar
# 218
# Arpa
# 216
# Prateek Kumar
# 216
# Aditya Purushottam
# 212
# Agham Chawla
# 210
# Kartikay Singh
# 210
# Joyneel Misra
# 210
# Anuyog Rohilla
# 210
# Satyam Mishra
# 210
# MOHIT SHARMA
# 208
# Shubham Chaudhary
# 208
# Sunil Maurya
# 208
# Piyush Gandhi
# 208
# Suyash bajpai
# 205
# kevin 111
# 200
# Raghu
# 200
# Anup Das
# 200
# Rohit Sharma
# 200
# Frez
# 200
# Shaswat Chaubey
# 200
# Jatin Khurana
# 200
# hardik agrawal
# 200
# Still.Hungry
# 200
# Mayank Garg
# 200
# Sai Bhava Teja Reddy Chinnangolla
# 200
# Rehas Sachdeva
# 200
# Aditya Pal
# 200
# shivam jain
# 200
# Rishabh Joshi
# 200
# Al Mamun Akash
# 200
# Hemanth Veeranki
# 200
# Vikram singh dhinwal
# 200
# Ayush Joshi
# 200
# Akhilesh Pandey
# 200
# ...
